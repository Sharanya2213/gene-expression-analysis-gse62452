# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_table(
    "GSE62452_series_matrix.txt",
    comment='!',
    sep='\t'
)

# %%
df.head()
# Out:
#     ID_REF  GSM1527105  GSM1527106  GSM1527107  GSM1527108  GSM1527109  \
# 0  7892501     2.49170     1.68604     2.09244     1.65016     2.00805
# 1  7892502     3.49655     3.85389     4.12626     3.84314     4.00303
# 2  7892503     1.66959     1.87758     3.08251     2.42303     1.56110
# 3  7892504     7.61535     7.95621     6.99696     8.13747     7.45826
# 4  7892505     1.73700     2.42442     2.26198     3.57889     2.24352
#
#    GSM1527110  GSM1527111  GSM1527112  GSM1527113  ...  GSM1527225  \
# 0     2.09908     2.15042     2.29071     2.25003  ...     1.90334
# 1     3.53426     3.86812     4.59975     4.60664  ...     4.06047
# 2     1.91609     2.29924     2.28101     3.85757  ...     2.30765
# 3     7.39392     7.33879     7.51678     7.70883  ...     7.25451
# 4     1.95949     2.33212     2.78334     2.05820  ...     2.17922
#
#    GSM1527226  GSM1527227  GSM1527228  GSM1527229  GSM1527230  GSM1527231  \
# ...

# %%
df.shape
# Out:
# (33297, 131)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 33297 entries, 0 to 33296
# Columns: 131 entries, ID_REF to GSM1527234
# dtypes: float64(130), int64(1)
# memory usage: 33.3 MB

# %%
df.columns
# Out:
# Index(['ID_REF', 'GSM1527105', 'GSM1527106', 'GSM1527107', 'GSM1527108',
#        'GSM1527109', 'GSM1527110', 'GSM1527111', 'GSM1527112', 'GSM1527113',
#        ...
#        'GSM1527225', 'GSM1527226', 'GSM1527227', 'GSM1527228', 'GSM1527229',
#        'GSM1527230', 'GSM1527231', 'GSM1527232', 'GSM1527233', 'GSM1527234'],
#       dtype='str', length=131)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df['ID_REF'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.iloc[:, 1:].dtypes.unique()
# Out:
# array([dtype('float64')], dtype=object)

# %%
df_ml=df.set_index("ID_REF").T

# %%
df_ml.shape
# Out:
# (130, 33297)

# %%
df_ml.reset_index(inplace=True)
